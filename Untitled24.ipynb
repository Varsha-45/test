# %%
import pandas as pd
import numpy as np
import warnings as w
w.filterwarnings("ignore")

# %%
ds = pd.read_csv(r"C:\Users\vkbal\Downloads\happiness_score_dataset.csv")

# %%
ds
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
ds.shape
# Out:
# (158, 12)

# %%
print("no. of rows is : ", ds.shape[0])
# Out:
# no. of rows is :  158

# %%
print("no. of columns is : ", ds.shape[1])
# Out:
# no. of columns is :  12

# %%
ds.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
ds.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
ds.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
ds.tail(4)
# Out:
#      Country                           Region  Happiness Rank  \
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# ...

# %%
ds.iloc[:, 2:3]
# Out:
#      Happiness Rank
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ..              ...
# 153             154
# 154             155
# 155             156
# 156             157
# 157             158
#
# [158 rows x 1 columns]

# %%
ds.iloc[:,:]
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
ds.iloc[ 0:2, :]
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
ds.loc[ 0:3, 'Region']
# Out:
# 0    Western Europe
# 1    Western Europe
# 2    Western Europe
# 3    Western Europe
# Name: Region, dtype: object

# %%
ds.loc[[8,9] , 'Region']
# Out:
# 8    Australia and New Zealand
# 9    Australia and New Zealand
# Name: Region, dtype: object

# %%
ds['Happiness Rank']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 153    154
# 154    155
# 155    156
# 156    157
# 157    158
# Name: Happiness Rank, Length: 158, dtype: int64

# %%
ds['Happiness Rank'].dtypes
# Out:
# dtype('int64')

# %%
ds['Happiness Rank'].head(5)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Happiness Rank, dtype: int64

# %%
ds.sample(6)
# Out:
#        Country                           Region  Happiness Rank  \
# 49       Italy                   Western Europe              50
# 59      Poland       Central and Eastern Europe              60
# 100  Swaziland               Sub-Saharan Africa             101
# 50     Bolivia      Latin America and Caribbean              51
# 109       Iran  Middle East and Northern Africa             110
# 28      France                   Western Europe              29
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 49             5.948         0.03914                   1.25114  1.19777
# 59             5.791         0.04263                   1.12555  1.27948
# 100            4.867         0.08742                   0.71206  1.07284
# 50             5.890         0.05642                   0.68133  0.97841
# 109            4.686         0.04449                   1.00880  0.54447
# 28             6.575         0.03512                   1.27778  1.26038
#
# ...

# %%
ds.loc[5, 'Country']
# Out:
# 'Finland'

# %%
ds.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
ds.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
ds['Country'][0] == 'Switzerland'
# Out:
# True

# %%
ds['Country'][0] = np.nan

# %%
ds
# Out:
#      Country                           Region  Happiness Rank  \
# 0        NaN                   Western Europe               1
# 1    Iceland                   Western Europe               2
# 2    Denmark                   Western Europe               3
# 3     Norway                   Western Europe               4
# 4     Canada                    North America               5
# ..       ...                              ...             ...
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# ...

# %%
ds.isnull().sum()
# Out:
# Country                          1
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
ds.drop([0], axis = 0, inplace = True)

# %%
ds
# Out:
#      Country                           Region  Happiness Rank  \
# 1    Iceland                   Western Europe               2
# 2    Denmark                   Western Europe               3
# 3     Norway                   Western Europe               4
# 4     Canada                    North America               5
# 5    Finland                   Western Europe               6
# ..       ...                              ...             ...
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# ...

# %%
ds['Happiness Score'].mean()
# Out:
# 5.361649681528663

# %%
ds['Happiness Score'].shape
# Out:
# (157,)

# %%
ds.iloc[3:9, 4]
# Out:
# 4    0.03553
# 5    0.03140
# 6    0.02799
# 7    0.03157
# 8    0.03371
# 9    0.04083
# Name: Standard Error, dtype: float64

# %%
ds['Happiness Score'].mode()
# Out:
# 0    5.192
# Name: Happiness Score, dtype: float64

# %%
ds['Freedom'].median()
# Out:
# 0.43477

# %%
ds.drop(['Country'], axis = 1, inplace = True)

# %%
ds
# Out:
#                               Region  Happiness Rank  Happiness Score  \
# 1                     Western Europe               2            7.561
# 2                     Western Europe               3            7.527
# 3                     Western Europe               4            7.522
# 4                      North America               5            7.427
# 5                     Western Europe               6            7.406
# ..                               ...             ...              ...
# 153               Sub-Saharan Africa             154            3.465
# 154               Sub-Saharan Africa             155            3.340
# 155  Middle East and Northern Africa             156            3.006
# 156               Sub-Saharan Africa             157            2.905
# 157               Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 1           0.04884                   1.30232  1.40223
# ...

# %%
ds.shape
# Out:
# (157, 11)

# %%
ds.dtypes
# Out:
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
ds.loc[ :4, ['Region', 'Happiness Rank']]
# Out:
#            Region  Happiness Rank
# 1  Western Europe               2
# 2  Western Europe               3
# 3  Western Europe               4
# 4   North America               5

# %%
ds[ds["Region"]== 'Western Europe']
# Out:
#              Region  Happiness Rank  Happiness Score  Standard Error  \
# 1    Western Europe               2            7.561         0.04884
# 2    Western Europe               3            7.527         0.03328
# 3    Western Europe               4            7.522         0.03880
# 5    Western Europe               6            7.406         0.03140
# 6    Western Europe               7            7.378         0.02799
# 7    Western Europe               8            7.364         0.03157
# 12   Western Europe              13            7.200         0.03751
# 16   Western Europe              17            6.946         0.03499
# 17   Western Europe              18            6.940         0.03676
# 18   Western Europe              19            6.937         0.03595
# 20   Western Europe              21            6.867         0.01866
# 25   Western Europe              26            6.750         0.01848
# 28   Western Europe              29            6.575         0.03512
# ...

# %%
ds[ds["Region"]== 'Western Europe'].shape
# Out:
# (20, 11)

# %%
da = pd.DataFrame(data = ds, columns = ['Region', 'Happiness Score'])

# %%
da
# Out:
#                               Region  Happiness Score
# 1                     Western Europe            7.561
# 2                     Western Europe            7.527
# 3                     Western Europe            7.522
# 4                      North America            7.427
# 5                     Western Europe            7.406
# ..                               ...              ...
# 153               Sub-Saharan Africa            3.465
# 154               Sub-Saharan Africa            3.340
# 155  Middle East and Northern Africa            3.006
# 156               Sub-Saharan Africa            2.905
# 157               Sub-Saharan Africa            2.839
#
# [157 rows x 2 columns]

# %%
ds.rename(columns = {'Happiness Score' : 'Score'})
# Out:
#                               Region  Happiness Rank  Score  Standard Error  \
# 1                     Western Europe               2  7.561         0.04884
# 2                     Western Europe               3  7.527         0.03328
# 3                     Western Europe               4  7.522         0.03880
# 4                      North America               5  7.427         0.03553
# 5                     Western Europe               6  7.406         0.03140
# ..                               ...             ...    ...             ...
# 153               Sub-Saharan Africa             154  3.465         0.03464
# 154               Sub-Saharan Africa             155  3.340         0.03656
# 155  Middle East and Northern Africa             156  3.006         0.05015
# 156               Sub-Saharan Africa             157  2.905         0.08658
# 157               Sub-Saharan Africa             158  2.839         0.06727
#
# ...

# %%
ds
# Out:
#                               Region  Happiness Rank  Happiness Score  \
# 1                     Western Europe               2            7.561
# 2                     Western Europe               3            7.527
# 3                     Western Europe               4            7.522
# 4                      North America               5            7.427
# 5                     Western Europe               6            7.406
# ..                               ...             ...              ...
# 153               Sub-Saharan Africa             154            3.465
# 154               Sub-Saharan Africa             155            3.340
# 155  Middle East and Northern Africa             156            3.006
# 156               Sub-Saharan Africa             157            2.905
# 157               Sub-Saharan Africa             158            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 1           0.04884                   1.30232  1.40223
# ...

# %%
ds.rename(columns = {'Happiness Score' : 'Score'}, inplace = True)

# %%
ds
# Out:
#                               Region  Happiness Rank  Score  Standard Error  \
# 1                     Western Europe               2  7.561         0.04884
# 2                     Western Europe               3  7.527         0.03328
# 3                     Western Europe               4  7.522         0.03880
# 4                      North America               5  7.427         0.03553
# 5                     Western Europe               6  7.406         0.03140
# ..                               ...             ...    ...             ...
# 153               Sub-Saharan Africa             154  3.465         0.03464
# 154               Sub-Saharan Africa             155  3.340         0.03656
# 155  Middle East and Northern Africa             156  3.006         0.05015
# 156               Sub-Saharan Africa             157  2.905         0.08658
# 157               Sub-Saharan Africa             158  2.839         0.06727
#
# ...

# %%
ds['Standard Error'].value_counts()
# Out:
# Standard Error
# 0.05051    2
# 0.04394    2
# 0.04934    2
# 0.03780    2
# 0.03751    2
#           ..
# 0.04114    1
# 0.04251    1
# 0.03843    1
# 0.05371    1
# 0.06727    1
# Name: count, Length: 152, dtype: int64

# %%
ds['Standard Error'].unique()
# Out:
# array([0.04884, 0.03328, 0.0388 , 0.03553, 0.0314 , 0.02799, 0.03157,
#        0.03371, 0.04083, 0.0347 , 0.04454, 0.03751, 0.04176, 0.03839,
#        0.04076, 0.03499, 0.03676, 0.03595, 0.03729, 0.01866, 0.05335,
#        0.06476, 0.0378 , 0.0491 , 0.01848, 0.058  , 0.06257, 0.03512,
#        0.04612, 0.04168, 0.04539, 0.05051, 0.03557, 0.04633, 0.03468,
#        0.04206, 0.03868, 0.04456, 0.09811, 0.10895, 0.05618, 0.05224,
#        0.04361, 0.04267, 0.03581, 0.04098, 0.04528, 0.05412, 0.03914,
#        0.05642, 0.03799, 0.04563, 0.04114, 0.04251, 0.03843, 0.05371,
#        0.04615, 0.03938, 0.04263, 0.0433 , 0.04394, 0.07832, 0.03135,
#        0.13693, 0.05635, 0.0558 , 0.05099, 0.05018, 0.04175, 0.07197,
#        0.04013, 0.02596, 0.03107, 0.03864, 0.03823, 0.04192, 0.03225,
#        0.03363, 0.03726, 0.04524, 0.05235, 0.02424, 0.06988, 0.06607,
#        0.04864, 0.04802, 0.0464 , 0.04934, 0.06161, 0.0342 , 0.05376,
# ...

# %%
ds['Standard Error'].nunique()
# Out:
# 152

# %%
ds.describe()
# Out:
#        Happiness Rank       Score  Standard Error  Economy (GDP per Capita)  \
# count      157.000000  157.000000      157.000000                157.000000
# mean        79.993631    5.361650        0.047972                  0.842632
# std         45.465752    1.134861        0.017165                  0.401988
# min          2.000000    2.839000        0.018480                  0.000000
# 25%         41.000000    4.518000        0.037290                  0.545580
# 50%         80.000000    5.212000        0.043940                  0.901980
# 75%        119.000000    6.168000        0.052320                  1.154060
# max        158.000000    7.561000        0.136930                  1.690420
#
#            Family  Health (Life Expectancy)     Freedom  \
# count  157.000000                157.000000  157.000000
# mean     0.988763                  0.628277    0.427106
# std      0.271720                  0.246605    0.149972
# min      0.000000                  0.000000    0.000000
# ...

# %%
ds['Region'][1] = 'India'

# %%
ds
# Out:
#                               Region  Happiness Rank  Score  Standard Error  \
# 1                              India               2  7.561         0.04884
# 2                     Western Europe               3  7.527         0.03328
# 3                     Western Europe               4  7.522         0.03880
# 4                      North America               5  7.427         0.03553
# 5                     Western Europe               6  7.406         0.03140
# ..                               ...             ...    ...             ...
# 153               Sub-Saharan Africa             154  3.465         0.03464
# 154               Sub-Saharan Africa             155  3.340         0.03656
# 155  Middle East and Northern Africa             156  3.006         0.05015
# 156               Sub-Saharan Africa             157  2.905         0.08658
# 157               Sub-Saharan Africa             158  2.839         0.06727
#
# ...
